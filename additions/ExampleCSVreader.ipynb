# %% [markdown]
# <a href="https://colab.research.google.com/github/cbishop4/MSE7530/blob/main/additions/ExampleCSVreader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
! git clone https://github.com/cbishop4/MSE7530/
# Out:
# Cloning into 'MSE7530'...
# remote: Enumerating objects: 108, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 108 (delta 37), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (108/108), 6.59 MiB | 9.98 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %% [markdown]
# In "sampledata" folder of the Class Repo. You may choose to download that file separately (which you can do from the sidebar here, or in the original GH Repo) to inspect its structure

# %%
fname = '/content/MSE7530/sampledata/HOPG30deg_Mangolini2016.csv'
# we can specify filenames as strings and assign them to variables
# (in this case, fname) for easier typing later

# %% [markdown]
# Load the CSV. This data is from a NEXAFS paper, https://pubs.acs.org/doi/10.1021/acs.analchem.5b04525 . This is a soft X-ray absorption technique that I specialize in, so I just had the data laying on my computer. I used a digitization app (https://automeris.io/) to pull the data to compare to a paper I was working on. Hopefully we will have time to cover NEXAFS in this class, but I'm always glad to talk about it if you want to know more.

# %%
loaded = pd.read_csv(fname)

# %%
loaded
# Out:
#      XrayEnergy (eV)    Absorption
# 0         271.950113 -1.069519e-02
# 1         274.217687 -1.069519e-02
# 2         277.120181 -8.880000e-16
# 3         279.931973 -8.880000e-16
# 4         281.564626  2.139037e-02
# ..               ...           ...
# 106       335.675571  9.653602e-01
# 107       336.598086  9.351441e-01
# 108       337.520602  9.094605e-01
# 109       338.443117  8.883092e-01
# 110       339.288756  8.707839e-01
#
# [111 rows x 2 columns]

# %% [markdown]
# Pandas loads files into **"dataframes"**. This is the main structure in Pandas. As Pandas is another one of those highly used Python packages, the documentation is really nice. Check out their main page: https://pandas.pydata.org/docs/index.html and use the "Getting Started" and "User guide" to learn the main concepts, working with dataframes, and find many tutorials.

# %% [markdown]
# The above was an easy import, because the header line was the first line. Before I use Colab's special dataframe functions, I'll show you how I would plot this in the olden days.

# %%
fig, ax = plt.subplots()
ax.plot(loaded['XrayEnergy (eV)'],loaded['Absorption'],'-o',markersize=2)
ax.set_xlabel('X-ray Energy (eV)'); ax.set_ylabel('Absorption')
ax.set_title('NEXAFS spectrum of HOPG at 30 $\\degree$ incidence')
# Out:
# Text(0.5, 1.0, 'NEXAFS spectrum of HOPG at 30 $\\degree$ incidence')

# %% [markdown]
# It looks like Colab also has some ways to interact with dataframes in more of a GUI (graphical user interface) format, in which you can do things with clicking rather than coding. **You should feel free to use these always.** To use them, just use the dataframe and click the buttons on the side. Experiment around with this. The nice thing is they automatically write some code in response to clicks.

# %%
loaded
# Out:
#      XrayEnergy (eV)    Absorption
# 0         271.950113 -1.069519e-02
# 1         274.217687 -1.069519e-02
# 2         277.120181 -8.880000e-16
# 3         279.931973 -8.880000e-16
# 4         281.564626  2.139037e-02
# ..               ...           ...
# 106       335.675571  9.653602e-01
# 107       336.598086  9.351441e-01
# 108       337.520602  9.094605e-01
# 109       338.443117  8.883092e-01
# 110       339.288756  8.707839e-01
#
# [111 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['XrayEnergy (eV)'].plot(kind='hist', bins=20, title='XrayEnergy (eV)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
from matplotlib import pyplot as plt
_df_4.plot(kind='scatter', x='XrayEnergy (eV)', y='Absorption', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Note that you need to have some idea of what you want to plot and what makes sense. Many of the suggested plots don't make any sense physically; this is something you need to build physical intuition for, which is why you need to know about how different measurements are made and what they're indicating.

# %% [markdown]
# The homework will give you plenty chance to practice this. Otherwise, you can find many .csv files online to practice with.
